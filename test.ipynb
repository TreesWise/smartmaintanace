# %%
import pandas as pd

# %%
data = pd.read_csv('./test_data/test_data_14.csv')

# %%
data
# Out:
#               signaldate        SOG        STW         COG   Slip_SOG  \
# 0    2022-07-26 11:00:00  17.541943  16.588890  355.859333 -46.424635
# 1    2022-07-26 12:00:00  17.405278  16.361110  144.948667 -45.406785
# 2    2022-07-26 13:00:00  18.383608  17.255555   22.604667 -55.086223
# 3    2022-07-26 14:00:00  16.038755  16.012500  237.790250 -42.604013
# 4    2022-07-28 12:00:00  17.352500  17.475000  163.619333 -44.853775
# ..                   ...        ...        ...         ...        ...
# 331  2022-09-10 09:00:00  18.651388  18.000000   66.705167 -42.078038
# 332  2022-09-10 10:00:00  18.548330  18.000000   68.554333 -41.225455
# 333  2022-09-10 11:00:00  18.831663  18.000000   67.067833 -43.302310
# 334  2022-09-10 12:00:00  19.168062  18.000000   67.662167 -46.129995
# 335  2022-09-10 13:00:00  17.658887  16.427780   67.721333 -55.023073
#
#       Slip_STW  Wind_speed  Wind_direction_relative  Rudder_angle  \
# ...

# %%
df
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df.loc[0, "c"] = 1

# %%
df
# Out:
#    a  b    c
# 0  1  4  1.0
# 1  2  5  NaN
# 2  3  6  NaN

# %%
df.iloc[0, 0]
# Out:
# 1
